# %%
# Load the TensorBoard notebook extension

#Uncomment to use it in colab and monitor to tendorboard
#%load_ext tensorboard

import tensorflow as tf
import datetime

# %% [markdown]
# ##Data preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import kerastuner as kt
from contextlib import redirect_stdout
import shutil

# %% [markdown]
# Define the path to load all locally stored csv with data from yahoo:

# %%
path = os.getcwd()+"/exper_files/datasets/" #Define where are the datasets

# %% [markdown]
# Create the dataset for each input layer:

# %%
def dataset_creation(crypto_list, pth):
    datasets = {} #Store all datasets here
    min_dates = {} #Store all minimum dates here
    max_dates = {} #Store all maximum dates here
    datasets_list = os.listdir(pth) #Find all dataset
    
    crypto_list = [elem+'.csv' for elem in crypto_list]

    for dataset in datasets_list:
        if dataset.endswith(".csv") and (dataset) in crypto_list:

            name = dataset.split(".")
            dataset_name = name[0]

            datasets[dataset_name] = pd.read_csv(pth + dataset) 

            datasets[dataset_name]['Date'] = pd.to_datetime(datasets[dataset_name]['Date'])
            datasets[dataset_name].fillna(method='ffill', inplace=True)

            #Create new columns 'close_off_high' and 'volatility' in order to make predictions more accurate:
            kwards = {'close_off_high': lambda x: 2 * (x['High'] - x['Close']) / (x['High'] - x['Low']) - 1,
              'volatility': lambda x: (x['High'] - x['Low']) / (x['Open'])
              }

            datasets[dataset_name] = datasets[dataset_name].assign(**kwards)
            
            datasets[dataset_name].fillna(-1, inplace=True) #Fill possible NaN close_off_high values with -1
                                                            #Because NaN values caused by (0/0)-1

            first_date = pd.to_datetime(datasets[dataset_name]['Date'][0])
            min_dates[dataset_name] = first_date
            
            last_date = pd.to_datetime(datasets[dataset_name]['Date'].iloc[-1])
            max_dates[dataset_name] = last_date

    max_date = max(min_dates.values(), key=lambda v: v)
    min_date = min(max_dates.values(), key=lambda v: v)

    #Drop all the data which are prior to max_date and later to min_date
    for dataset in datasets:
        datasets[dataset] = datasets[dataset][(datasets[dataset]['Date'] >= max_date) & 
                                              (datasets[dataset]['Date'] <= min_date)]


    #Compute the average and standard deviation of 'Close' value for the last 7-days and 30-days(month): 
    for dataset in datasets:

        temp = datasets[dataset].copy()

        #Drop the first 30 days to be able to compute average and standard deviation of month for the rows of the table
        temp = temp[29:]

        temp['mean_7days_Close'] = datasets[dataset]['Close'].rolling(window=7).mean()

        temp['mean_month_Close'] = datasets[dataset]['Close'].rolling(window=30).mean()

        temp['std_7days_Close'] = datasets[dataset]['Close'].rolling(window=7).std()

        temp['std_month_Close'] = datasets[dataset]['Close'].rolling(window=30).std()

        datasets[dataset] = temp.copy()
        



    #Rename the columns
    for dataset in datasets:

        datasets[dataset] = datasets[dataset].rename(columns={'Close':dataset+'_Close', 'Open':dataset+'_Open', 
                                                              'High':dataset+'_High', 'Low':dataset+'_Low', 
                                                              'Adj Close':dataset+'_Adj_Close', 
                                                              'Volume':dataset+'_Volume', 
                                                              'close_off_high':dataset+'_close_off_high',
                                                              'volatility':dataset+'_volatility',
                                                              'mean_7days_Close':dataset+'_mean_7days_Close',
                                                              'mean_month_Close':dataset+'_mean_month_Close',
                                                              'std_7days_Close':dataset+'_std_7days_Close',
                                                              'std_month_Close':dataset+'_std_month_Close'})
        
    
   
    return datasets

# %% [markdown]
# Split data into training, validation and test set:

# %%
def split_data(perc_train_set, perc_val_set, dict_currency_data):
        
        dict_tr_set = {}
        dict_val_set = {}
        dict_tst_set = {}
        
        for coin, currency_data in dict_currency_data.items():
            
            #Compute the date to split the dataset into training and validation_test set based on 'perc_train_set'
            splt_date_train = currency_data.iloc[round(currency_data.shape[0] * perc_train_set)]['Date']

            #Split the dataset into trainning and validation_test set
            tr_set, val_tst_set = currency_data[currency_data['Date'] < splt_date_train], \
                             currency_data[currency_data['Date'] >= splt_date_train]

            #Compute the date to split the val_tst_set into validation and test set based on 'perc_val_set'
            splt_date_val = val_tst_set.iloc[round(val_tst_set.shape[0] * perc_val_set)]['Date']

            #Split the val_tst_set into validation and test set        
            val_set, tst_set = val_tst_set[val_tst_set['Date'] < splt_date_val], \
                                val_tst_set[val_tst_set['Date'] >= splt_date_val]
            
            
            
            #Drop 'Date' column and save train, validation and test sets of each coin at the corresponding dictionary 
            tr_set = ((tr_set.drop(['Date'], axis=1)).reset_index()).drop(['index'], axis=1)
            dict_tr_set[coin] = tr_set
            
            val_set = ((val_set.drop(['Date'], axis=1)).reset_index()).drop(['index'], axis=1)
            dict_val_set[coin] = val_set
            
            tst_set = ((tst_set.drop(['Date'], axis=1)).reset_index()).drop(['index'], axis=1)
            dict_tst_set[coin] = tst_set
        
        return dict_tr_set, dict_val_set, dict_tst_set, splt_date_train, splt_date_val

# %% [markdown]
# Normalize training, validation and test inputs and outputs with sliding window:

# %%
def normalize_in_out(prd_range, wind_len, dict_tr_set, dict_val_set, dict_tst_set, target_feats, coin_targ, crypto_list):
    
    dict_LSTM_tr_in = {}
    dict_LSTM_val_in = {}
    dict_LSTM_test_in = {}
    
    
    for crypto in crypto_list:
        
        tr_set = dict_tr_set[crypto]
        val_set = dict_val_set[crypto]
        tst_set = dict_tst_set[crypto]
        
        all_feats = tr_set.columns #Get all features
        feats = [crypto+"_"+feat for feat in target_feats] #Get the features in the appropriate format 
                                                           #(e.g 'Close' --> 'BTC-USD_Close')
        
        
        #Normalize training inputs
        LSTM_tr_in = []
        for i in range(len(tr_set) - wind_len):
            tmp_set = tr_set[i:(i + wind_len)].copy()

            for col in all_feats:
                if col not in feats:
                    tmp_set = tmp_set.drop([col], axis=1) #Drop the feature that will not be used

            for col in feats:
                tmp_set[:][col] = tmp_set[col] / tmp_set[col].iloc[0] - 1 #Normalize the feature that will be used

            LSTM_tr_in.append(tmp_set)

        #Transform from DataFrame to numpy array
        LSTM_tr_in = [np.array(LSTM_tr_i) for LSTM_tr_i in LSTM_tr_in]
        LSTM_tr_in = np.array(LSTM_tr_in)
        
        dict_LSTM_tr_in[crypto] = LSTM_tr_in


        #Normalize validation inputs
        LSTM_val_in = []
        for i in range(len(val_set) - wind_len):
            tmp_set = val_set[i:(i + wind_len)].copy()

            for col in all_feats:
                if col not in feats:
                    tmp_set = tmp_set.drop([col], axis=1) #Drop the feature that will not be used

            for col in feats:
                tmp_set[:][col] = tmp_set[col] / tmp_set[col].iloc[0] - 1 #Normalize the feature that will be used

            LSTM_val_in.append(tmp_set)

        #Transform from DataFrame to numpy array
        LSTM_val_in = [np.array(LSTM_val_i) for LSTM_val_i in LSTM_val_in]
        LSTM_val_in = np.array(LSTM_val_in)
        
        dict_LSTM_val_in[crypto] = LSTM_val_in

        #Normalize test inputs
        LSTM_test_in = []
        for i in range(len(tst_set) - wind_len):
            tmp_set = tst_set[i:(i + wind_len)].copy() 

            for col in all_feats:
                if col not in feats:

                    tmp_set = tmp_set.drop([col], axis=1) #Drop the feature that will not be used

            for col in feats:
                tmp_set[:][col] = tmp_set[col] / tmp_set[col].iloc[0] - 1 #Normalize the feature that will be used

            LSTM_test_in.append(tmp_set)


        #Transform from DataFrame to numpy array
        LSTM_test_in = [np.array(LSTM_test_i) for LSTM_test_i in LSTM_test_in]
        LSTM_test_in = np.array(LSTM_test_in)
        
        dict_LSTM_test_in[crypto] = LSTM_test_in 
    
    
    tr_set = dict_tr_set[coin_targ].copy()
    val_set = dict_val_set[coin_targ].copy()
    
    #Normalize training outputs
    LSTM_rangd_train_out = []
    for i in range(wind_len, len(tr_set[coin_targ+'_Close']) - prd_range):
        LSTM_rangd_train_out.append((tr_set[coin_targ+'_Close'][i:i+prd_range].values/tr_set[coin_targ+'_Close'][tr_set.index[0]+i-wind_len]) - 1)

    LSTM_rangd_train_out = np.array(LSTM_rangd_train_out)
    
    
    #Normalize validation outputs
    LSTM_rangd_val_out = []
    for i in range(wind_len, len(val_set[coin_targ+'_Close']) - prd_range):
        LSTM_rangd_val_out.append((val_set[coin_targ+'_Close'][i:i+prd_range].values/val_set[coin_targ+'_Close'][val_set.index[0]+i-wind_len]) - 1)
    
    LSTM_rangd_val_out = np.array(LSTM_rangd_val_out)
    
    return LSTM_rangd_train_out, LSTM_rangd_val_out, dict_LSTM_tr_in, dict_LSTM_val_in, dict_LSTM_test_in

# %% [markdown]
# Create MAE plot:

# %%
def create_plot(rangd_h, path_to_sav, target_cn):
    
    fig, ax1 = plt.subplots(1, 1, figsize=(25, 10))

    ax1.plot(rangd_h.epoch, rangd_h.history['loss'], color='b', label='Loss')
    ax1.plot(rangd_h.epoch, rangd_h.history['val_loss'], color='orange', label='Val_loss')
    ax1.set_xticks(range(0, len(rangd_h.epoch)))
    ax1.set_title('Training Error')
    ax1.set_ylabel('Mean Absolute Error (MAE)', fontsize=12)
    ax1.set_xlabel('#Epoch', fontsize=12)
    #plt.legend()
    plt.savefig(path_to_sav+"/"+target_cn+'_MAE.png')
    plt.close(fig)
    #plt.show()

# %% [markdown]
# Define, build and train model

# %%
########Model with CNN layers, followed by LSTM layers, followed by Dense layers #####################
from keras.models import Sequential
from keras.layers import Activation, Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow as tf
from keras.layers import Conv1D
from keras.layers import MaxPool1D
from keras.layers import AveragePooling1D
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.models import Model
from keras import Input


def model_tuning(coin_list, inputs, outputs, output_size, validation_inputs, validation_outputs, epochs, early_stop_patience, 
                 neurons, dropout, prd_range, batch_size, keras_tuner_dir, activ_func="linear", loss="mae", 
                 optimizer="adam"):
    
    def build_model(hp):
        
        separate_coin_layers = {}
        
        neurLSTM1 = hp.Choice('neurons_1_LSTM', values=neurons)
        
        for coin in coin_list:
                       
            #Input layer for each coin with each own data
            separate_coin_layers[coin] = {}
            separate_coin_layers[coin]['input'] = Input(shape=((inputs[coin].shape[1], inputs[coin].shape[2])),
                                                             name="input_"+coin)
            #model = Sequential()

            #filters_conv1 = hp.Choice('filters_Conv1', values=[16, 32, 64])
            #kernel_size_conv1 = hp.Choice('kernel_size_Conv1', values=[2, 3, 5])
            #strides_conv1 = hp.Choice('strides_Conv1', values=[1, 2, 3])
            #model.add(Conv1D(filters=filters_conv1, kernel_size=kernel_size_conv1, strides=strides_conv1, 
            #                 activation='relu',
            #                 input_shape=(inputs.shape[1], inputs.shape[2])))


            #moment_batchNormConv1 = hp.Float('momentum_batchNormConv1', min_value=0.09, max_value=0.99, step=0.1)
            #model.add(BatchNormalization(momentum=moment_batchNormConv1))

            #pool_size_maxPool1 = hp.Choice('pool_size_MaxPool1', values=[2, 3, 4])
            #model.add(MaxPool1D(pool_size=2))
            #model.add(AveragePooling1D(pool_size=2))

            
            separate_coin_layers[coin]['LSTM1'] = LSTM(neurLSTM1)(separate_coin_layers[coin]['input']) #, input_shape=(inputs[coin].shape[1], inputs[coin].shape[2]) #return_sequences=True

            #dropLSTM1 = hp.Choice('dropout_LSTM_1_'+coin, values=dropout)
            #model.add(Dropout(dropLSTM1))

            #neurLSTM2 = hp.Choice('neurons_2_LSTM', values=neurons)
            #model.add(LSTM(neurLSTM2))

            #dropLSTM2 = hp.Choice('dropout_LSTM_2', values=dropout)
            #model.add(Dropout(dropLSTM2))

            #moment_batchNormLSTM2 = hp.Float('momentum_batchNormLSTM2', min_value=0.09, max_value=0.99, step=0.1)
            #model.add(BatchNormalization(momentum=moment_batchNormLSTM2))

                      
        # Merge all available features into a single large vector via concatenation
        conc_layer_output = Concatenate()([separate_coin_layers[coin]['LSTM1'] for coin in coin_list])
        
        neurD1 = hp.Choice('neurons_1_Dense', values=[32, 64, 128, 256])
        dense1_output = Dense(units=neurD1, activation='relu')(conc_layer_output)
        
        #dropDense1 = hp.Choice('dropout_Dense_1', values=dropout)
        #model.add(Dropout(dropDense1))
        
        #moment_batchNormDense1 = hp.Float('momentum_batchNormDense1', min_value=0.09, max_value=0.99, step=0.1)
        #model.add(BatchNormalization(momentum=moment_batchNormDense1))
        
        neurD2 = hp.Choice('neurons_2_Dense', values=[32, 64, 128, 256])
        dense2_output = Dense(units=neurD2, activation='relu')(dense1_output)
        
        #dropDense2 = hp.Choice('dropout_Dense_2', values=dropout)
        #model.add(Dropout(dropDense2))
        
        #moment_batchNormDense2 = hp.Float('momentum_batchNormDense2', min_value=0.09, max_value=0.99, step=0.1)
        #model.add(BatchNormalization(momentum=moment_batchNormDense2))
        
        final_output = Dense(units=output_size, activation=activ_func)(dense2_output)
        
        overall_model = Model([separate_coin_layers[coin]['input'] for coin in coin_list], final_output)
        
        hp_learning_rate = hp.Float(name='learning_rate', min_value=0.0001, max_value=0.05, step=0.0005)
        
        hp_beta_1 = hp.Float('beta_1', min_value=0.85, max_value=0.95, step=0.01)
        
        hp_beta_2 = hp.Float('beta_2', min_value=0.98, max_value=0.999, step=0.001)
        
        hp_epsilon = hp.Float('epsilon', min_value=1e-07, max_value=1e-08, sampling='LOG')
        
        optimizer = tf.keras.optimizers.Adam(
        learning_rate=hp_learning_rate, beta_1=hp_beta_1, beta_2=hp_beta_2, epsilon=hp_epsilon)
        
        overall_model.compile(loss=loss, optimizer=optimizer)
        return overall_model
    
    
    
    #Create_tuner
    tuner = kt.Hyperband(build_model,
                 objective='val_loss',
                 max_epochs=epochs,
                 factor=3,
                 directory=keras_tuner_dir,
                 project_name='keras_tuner')

    stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=early_stop_patience)

    tuner.search([inputs[coin][:-prd_range] for coin in coin_list], outputs, 
                 validation_data=([validation_inputs[coin][:-prd_range] for coin in coin_list], validation_outputs), 
                 epochs=epochs, batch_size=batch_size, callbacks=[stop_early],
                 use_multiprocessing=True,
                 workers=8)

    # Get the optimal hyperparameters
    best_hps=tuner.get_best_hyperparameters(num_trials=3)[0]

    
    return best_hps, tuner

# %% [markdown]
# Overall run:

# %%
#Get data
crypto_list = [['BTC-USD', 'ETH-USD', 'DOGE-USD', 'USDT-USD','XRP-USD', 'LTC-USD', 'XLM-USD']] #Define the sets of cryptocurrencies to be tested

first_txt_flag = 0


for cryptocurrency_list in crypto_list:
    
    cryptocurrency_list_output = 'Using cryptocurrencies: '+str(cryptocurrency_list)
    print(cryptocurrency_list_output)
    data = dataset_creation(cryptocurrency_list, path)

    #Split data
    percent_train_set = 0.8
    percent_val_set = 0.5

    training_set, validation_set, test_set, split_date_train, split_date_valid = split_data(percent_train_set, 
                                                                                           percent_val_set, data)

    
    features_list = [['Close', 'Open', 'High']]
    """[['Close'], ['Close', 'Volume'], ['Close', 'Open', 'High'],
                     ['Close', 'close_off_high', 'volatility'],
                     ['Close', 'mean_7days_Close', 'mean_month_Close'],
                     ['Close', 'std_7days_Close', 'std_month_Close']]""" #Define the sets of features to be tested 
    
    for featurs in features_list: 
        
        new_txt_flag = 0 
        
        featurs_output = '\tUsing the features: '+str(featurs)
        print('\tUsing the features: '+str(featurs))
        
        
        #Create inputs and outputs for the model training, validation and testing
        pred_range = 5
        window_len = 10
        features = featurs
        coin_target = 'BTC-USD'
        
        

        LSTM_ranged_training_outputs, LSTM_ranged_validation_outputs, LSTM_training_inputs, LSTM_validation_inputs, LSTM_test_inputs = normalize_in_out(
                                                                                                      pred_range, window_len, 
                                                                                                      training_set, 
                                                                                                      validation_set, 
                                                                                                      test_set, 
                                                                                                      features, coin_target,
                                                                                                      cryptocurrency_list)

        
        batch_size_list = [64] #[1, 32, 64]
        neuron_list = [20, 40, 60, 100]
        dropout_list = [0.0, 0.1, 0.2, 0.25, 0.3, 0.4]
        early_stop_patience = 10
        epochs = 100
        
        
        
        
        
        for bat_s in batch_size_list:

            #Build and train model
            epochs = 500
            batch_size = bat_s
            early_stop_patience = 10
            shuffle = True
            verbose = 0
            
            exper_params_output = '\t\tBatch_size: '+str(batch_size)
            print(exper_params_output)
           
            
            #Path to write log files
            cur_path = os.getcwd()+'/'
            log_dir = cur_path + "logs/fit/" + str(cryptocurrency_list) + '/' + str(featurs) + '/' + 'Batch_size='+str(batch_size)
            if not os.path.exists(log_dir):
                os.makedirs(log_dir)
            
            #Path to save its checkpoints the keras_tuner because it raises an error when it is in the current working
            #directory or in a sub-folder
            keras_tuner_dir = 'C:\keras_tuner'
            if not os.path.exists(keras_tuner_dir):
                os.makedirs(keras_tuner_dir)
            
            best_hps, tuner = model_tuning(cryptocurrency_list, inputs=LSTM_training_inputs, outputs=LSTM_ranged_training_outputs,
                                output_size=pred_range, 
                                validation_inputs = LSTM_validation_inputs, 
                                validation_outputs = LSTM_ranged_validation_outputs,
                                epochs=epochs, early_stop_patience=early_stop_patience, neurons=neuron_list, 
                                dropout=dropout_list, prd_range=pred_range, batch_size=bat_s, 
                                           keras_tuner_dir=keras_tuner_dir)
        
            exper_outputs = "\t\tThe hyperparameter search is complete. The optimal parameter were found to be: \n" + \
                            str(tuner.oracle.get_best_trials(num_trials=1)[0].hyperparameters.values)
        
            
            
            # Build the model with the optimal hyperparameters and train it
            best_model = tuner.hypermodel.build(best_hps)
            mod_history = best_model.fit([LSTM_training_inputs[coin][:-pred_range] for coin in cryptocurrency_list], 
                                         LSTM_ranged_training_outputs, 
                                         validation_data=([LSTM_validation_inputs[coin][:-pred_range] 
                                                           for coin in cryptocurrency_list], 
                                                          LSTM_ranged_validation_outputs), 
                                         epochs=epochs)
            
            #Get the epoch with the best validation loss
            val_loss_per_epoch = mod_history.history['val_loss']
            best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
            exper_outputs += '\n\n\t\tBest epoch: '+ str(best_epoch) + ' with validation loss: ' + str((min(val_loss_per_epoch)))
            
            #Print results to a .txt file
            if first_txt_flag == 0:
                
                if new_txt_flag == 0:
                    
                    #Create a .txt file and write the results
                    txt_log_dir = "logs/fit/" + str(cryptocurrency_list) + '/' + str(featurs) + '/'
                    f = open(txt_log_dir+"/"+coin_target+"_results.txt", "w")
                    f.write(cryptocurrency_list_output)
                    f.write("\n"+featurs_output)
                    
                    first_txt_flag += 1
                    new_txt_flag += 1
            else:
                
                if new_txt_flag == 0:
                    
                    f.close() #Close previous txt file
                    
                    #Create a .txt file and write the results
                    txt_log_dir = "logs/fit/" + str(cryptocurrency_list) + '/' + str(featurs) + '/'
                    f = open(txt_log_dir+"/"+coin_target+"_results.txt", "w")
                    f.write(cryptocurrency_list_output)
                    f.write("\n"+featurs_output)
                    
                    new_txt_flag += 1
                    
                
            
            f.write("\n"+exper_params_output)
            f.write("\n"+exper_outputs)
            
            f.write("\n\nFull keras tuner results: \n")
            with redirect_stdout(f): 
                tuner.results_summary()
            
            
            create_plot(mod_history, log_dir, coin_target)

f.close()


#Write best model summary to a txt file
with open(cur_path + 'logs/fit/modelsummary.txt', 'w') as f_sum:
    with redirect_stdout(f_sum):
        best_model.summary()
        

#Remove folder with is created by keras tuner
shutil.rmtree(keras_tuner_dir)
# Out:
# Trial 725 Complete [00h 00m 22s]
# val_loss: 0.03547787666320801
#
# Best val_loss So Far: 0.03500007092952728
# Total elapsed time: 03h 28m 07s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/500
# 52/52 [==============================] - 12s 54ms/step - loss: 0.0786 - val_loss: 0.0412
# Epoch 2/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0560 - val_loss: 0.0387
# Epoch 3/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0509 - val_loss: 0.0381
# Epoch 4/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0485 - val_loss: 0.0366
# Epoch 5/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0502 - val_loss: 0.0370
# Epoch 6/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0466 - val_loss: 0.0382
# Epoch 7/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0460 - val_loss: 0.0363
# Epoch 8/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0472 - val_loss: 0.0360
# Epoch 9/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0465 - val_loss: 0.0370
# Epoch 10/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0456 - val_loss: 0.0358
# Epoch 11/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0451 - val_loss: 0.0387
# Epoch 12/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0484 - val_loss: 0.0371
# Epoch 13/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0441 - val_loss: 0.0378
# Epoch 14/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0465 - val_loss: 0.0419
# Epoch 15/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0472 - val_loss: 0.0400
# Epoch 16/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0461 - val_loss: 0.0362
# Epoch 17/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0436 - val_loss: 0.0377
# Epoch 18/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0435 - val_loss: 0.0362
# Epoch 19/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0419 - val_loss: 0.0394
# Epoch 20/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0434 - val_loss: 0.0366
# Epoch 21/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0420 - val_loss: 0.0355
# Epoch 22/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0408 - val_loss: 0.0357
# Epoch 23/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0406 - val_loss: 0.0374
# Epoch 24/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0385 - val_loss: 0.0367
# Epoch 25/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0384 - val_loss: 0.0371
# Epoch 26/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0391 - val_loss: 0.0365
# Epoch 27/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0402 - val_loss: 0.0382
# Epoch 28/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0413 - val_loss: 0.0382
# Epoch 29/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0394 - val_loss: 0.0374
# Epoch 30/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0386 - val_loss: 0.0399
# Epoch 31/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0376 - val_loss: 0.0379
# Epoch 32/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0365 - val_loss: 0.0383
# Epoch 33/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0378 - val_loss: 0.0371
# Epoch 34/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0355 - val_loss: 0.0384
# Epoch 35/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0369 - val_loss: 0.0400
# Epoch 36/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0354 - val_loss: 0.0389
# Epoch 37/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0358 - val_loss: 0.0379
# Epoch 38/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0325 - val_loss: 0.0391
# Epoch 39/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0340 - val_loss: 0.0386
# Epoch 40/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0333 - val_loss: 0.0393
# Epoch 41/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0325 - val_loss: 0.0393
# Epoch 42/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0326 - val_loss: 0.0392
# Epoch 43/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0295 - val_loss: 0.0435
# Epoch 44/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0346 - val_loss: 0.0380
# Epoch 45/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0311 - val_loss: 0.0416
# Epoch 46/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0306 - val_loss: 0.0421
# Epoch 47/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0305 - val_loss: 0.0410
# Epoch 48/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0286 - val_loss: 0.0397
# Epoch 49/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0282 - val_loss: 0.0402
# Epoch 50/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0285 - val_loss: 0.0401
# Epoch 51/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0279 - val_loss: 0.0398
# Epoch 52/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0265 - val_loss: 0.0404
# Epoch 53/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0251 - val_loss: 0.0414
# Epoch 54/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0280 - val_loss: 0.0391
# Epoch 55/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0277 - val_loss: 0.0413
# Epoch 56/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0276 - val_loss: 0.0417
# Epoch 57/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0273 - val_loss: 0.0408
# Epoch 58/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0272 - val_loss: 0.0427
# Epoch 59/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0254 - val_loss: 0.0426
# Epoch 60/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0230 - val_loss: 0.0407
# Epoch 61/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0244 - val_loss: 0.0395
# Epoch 62/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0249 - val_loss: 0.0435
# Epoch 63/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0259 - val_loss: 0.0442
# Epoch 64/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0234 - val_loss: 0.0435
# Epoch 65/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0243 - val_loss: 0.0430
# Epoch 66/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0246 - val_loss: 0.0431
# Epoch 67/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0238 - val_loss: 0.0415
# Epoch 68/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0221 - val_loss: 0.0421
# Epoch 69/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0252 - val_loss: 0.0416
# Epoch 70/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0230 - val_loss: 0.0410
# Epoch 71/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0223 - val_loss: 0.0413
# Epoch 72/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0220 - val_loss: 0.0422
# Epoch 73/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0210 - val_loss: 0.0423
# Epoch 74/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0211 - val_loss: 0.0433
# Epoch 75/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0215 - val_loss: 0.0426
# Epoch 76/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0205 - val_loss: 0.0414
# Epoch 77/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0208 - val_loss: 0.0429
# Epoch 78/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0217 - val_loss: 0.0435
# Epoch 79/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0224 - val_loss: 0.0450
# Epoch 80/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0208 - val_loss: 0.0429
# Epoch 81/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0208 - val_loss: 0.0413
# Epoch 82/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0226 - val_loss: 0.0453
# Epoch 83/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0204 - val_loss: 0.0449
# Epoch 84/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0211 - val_loss: 0.0429
# Epoch 85/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0201 - val_loss: 0.0446
# Epoch 86/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0205 - val_loss: 0.0426
# Epoch 87/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0188 - val_loss: 0.0419
# Epoch 88/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0186 - val_loss: 0.0423
# Epoch 89/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0177 - val_loss: 0.0430
# Epoch 90/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0189 - val_loss: 0.0460
# Epoch 91/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0184 - val_loss: 0.0420
# Epoch 92/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0183 - val_loss: 0.0431
# Epoch 93/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0181 - val_loss: 0.0432
# Epoch 94/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0200 - val_loss: 0.0426
# Epoch 95/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0198 - val_loss: 0.0419
# Epoch 96/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0191 - val_loss: 0.0446
# Epoch 97/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0175 - val_loss: 0.0422
# Epoch 98/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0184 - val_loss: 0.0420
# Epoch 99/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0174 - val_loss: 0.0426
# Epoch 100/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0177 - val_loss: 0.0435
# Epoch 101/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0198 - val_loss: 0.0423
# Epoch 102/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0190 - val_loss: 0.0444
# Epoch 103/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0167 - val_loss: 0.0435
# Epoch 104/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0167 - val_loss: 0.0441
# Epoch 105/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0160 - val_loss: 0.0422
# Epoch 106/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0171 - val_loss: 0.0448
# Epoch 107/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0172 - val_loss: 0.0437
# Epoch 108/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0173 - val_loss: 0.0446
# Epoch 109/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0166 - val_loss: 0.0425
# Epoch 110/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0161 - val_loss: 0.0450
# Epoch 111/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0163 - val_loss: 0.0426
# Epoch 112/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0164 - val_loss: 0.0455
# Epoch 113/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0158 - val_loss: 0.0426
# Epoch 114/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0151 - val_loss: 0.0440
# Epoch 115/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0160 - val_loss: 0.0446
# Epoch 116/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0159 - val_loss: 0.0447
# Epoch 117/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0163 - val_loss: 0.0424
# Epoch 118/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0172 - val_loss: 0.0456
# Epoch 119/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0160 - val_loss: 0.0439
# Epoch 120/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0156 - val_loss: 0.0448
# Epoch 121/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0147 - val_loss: 0.0433
# Epoch 122/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0152 - val_loss: 0.0431
# Epoch 123/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0156 - val_loss: 0.0432
# Epoch 124/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0157 - val_loss: 0.0432
# Epoch 125/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0147 - val_loss: 0.0442
# Epoch 126/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0155 - val_loss: 0.0431
# Epoch 127/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0159 - val_loss: 0.0442
# Epoch 128/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0148 - val_loss: 0.0433
# Epoch 129/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0161 - val_loss: 0.0448
# Epoch 130/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0158 - val_loss: 0.0441
# Epoch 131/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0150 - val_loss: 0.0444
# Epoch 132/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0151 - val_loss: 0.0444
# Epoch 133/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0148 - val_loss: 0.0439
# Epoch 134/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0153 - val_loss: 0.0429
# Epoch 135/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0168 - val_loss: 0.0433
# Epoch 136/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0147 - val_loss: 0.0444
# Epoch 137/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0140 - val_loss: 0.0422
# Epoch 138/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0133 - val_loss: 0.0450
# Epoch 139/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0141 - val_loss: 0.0436
# Epoch 140/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0133 - val_loss: 0.0446
# Epoch 141/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0156 - val_loss: 0.0443
# Epoch 142/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0150 - val_loss: 0.0440
# Epoch 143/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0138 - val_loss: 0.0427
# Epoch 144/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0134 - val_loss: 0.0440
# Epoch 145/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0127 - val_loss: 0.0460
# Epoch 146/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0146 - val_loss: 0.0454
# Epoch 147/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0143 - val_loss: 0.0450
# Epoch 148/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0145 - val_loss: 0.0423
# Epoch 149/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0139 - val_loss: 0.0449
# Epoch 150/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0149 - val_loss: 0.0448
# Epoch 151/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0136 - val_loss: 0.0441
# Epoch 152/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0135 - val_loss: 0.0448
# Epoch 153/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0124 - val_loss: 0.0447
# Epoch 154/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0130 - val_loss: 0.0469
# Epoch 155/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0137 - val_loss: 0.0461
# Epoch 156/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0151 - val_loss: 0.0456
# Epoch 157/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0139 - val_loss: 0.0457
# Epoch 158/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0129 - val_loss: 0.0445
# Epoch 159/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0126 - val_loss: 0.0458
# Epoch 160/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0125 - val_loss: 0.0440
# Epoch 161/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0440
# Epoch 162/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0132 - val_loss: 0.0461
# Epoch 163/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0132 - val_loss: 0.0453
# Epoch 164/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0135 - val_loss: 0.0443
# Epoch 165/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0137 - val_loss: 0.0466
# Epoch 166/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0130 - val_loss: 0.0435
# Epoch 167/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0130 - val_loss: 0.0459
# Epoch 168/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0130 - val_loss: 0.0463
# Epoch 169/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0138 - val_loss: 0.0448
# Epoch 170/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0450
# Epoch 171/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0464
# Epoch 172/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0134 - val_loss: 0.0440
# Epoch 173/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0139 - val_loss: 0.0449
# Epoch 174/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0124 - val_loss: 0.0455
# Epoch 175/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0128 - val_loss: 0.0439
# Epoch 176/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0446
# Epoch 177/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0143 - val_loss: 0.0449
# Epoch 178/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0448
# Epoch 179/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0121 - val_loss: 0.0444
# Epoch 180/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0455
# Epoch 181/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0135 - val_loss: 0.0456
# Epoch 182/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0122 - val_loss: 0.0427
# Epoch 183/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0434
# Epoch 184/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0448
# Epoch 185/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0127 - val_loss: 0.0454
# Epoch 186/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0135 - val_loss: 0.0459
# Epoch 187/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0142 - val_loss: 0.0443
# Epoch 188/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0121 - val_loss: 0.0434
# Epoch 189/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0124 - val_loss: 0.0453
# Epoch 190/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0451
# Epoch 191/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0124 - val_loss: 0.0433
# Epoch 192/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0132 - val_loss: 0.0445
# Epoch 193/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0118 - val_loss: 0.0453
# Epoch 194/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0120 - val_loss: 0.0450
# Epoch 195/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0458
# Epoch 196/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0112 - val_loss: 0.0441
# Epoch 197/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0444
# Epoch 198/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0455
# Epoch 199/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0131 - val_loss: 0.0453
# Epoch 200/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0118 - val_loss: 0.0446
# Epoch 201/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0113 - val_loss: 0.0447
# Epoch 202/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0436
# Epoch 203/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0120 - val_loss: 0.0435
# Epoch 204/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0112 - val_loss: 0.0440
# Epoch 205/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0120 - val_loss: 0.0449
# Epoch 206/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0118 - val_loss: 0.0451
# Epoch 207/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0454
# Epoch 208/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0461
# Epoch 209/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0107 - val_loss: 0.0455
# Epoch 210/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0121 - val_loss: 0.0458
# Epoch 211/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0118 - val_loss: 0.0446
# Epoch 212/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0101 - val_loss: 0.0449
# Epoch 213/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0112 - val_loss: 0.0456
# Epoch 214/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0470
# Epoch 215/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0111 - val_loss: 0.0438
# Epoch 216/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0110 - val_loss: 0.0456
# Epoch 217/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0109 - val_loss: 0.0450
# Epoch 218/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0116 - val_loss: 0.0450
# Epoch 219/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0103 - val_loss: 0.0447
# Epoch 220/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0443
# Epoch 221/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0114 - val_loss: 0.0452
# Epoch 222/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0113 - val_loss: 0.0444
# Epoch 223/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0118 - val_loss: 0.0469
# Epoch 224/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0457
# Epoch 225/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0121 - val_loss: 0.0465
# Epoch 226/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0113 - val_loss: 0.0458
# Epoch 227/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0109 - val_loss: 0.0447
# Epoch 228/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0445
# Epoch 229/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0447
# Epoch 230/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0451
# Epoch 231/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0119 - val_loss: 0.0447
# Epoch 232/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0443
# Epoch 233/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0100 - val_loss: 0.0448
# Epoch 234/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0464
# Epoch 235/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0107 - val_loss: 0.0454
# Epoch 236/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0110 - val_loss: 0.0450
# Epoch 237/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0106 - val_loss: 0.0436
# Epoch 238/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0105 - val_loss: 0.0446
# Epoch 239/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0103 - val_loss: 0.0439
# Epoch 240/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0098 - val_loss: 0.0440
# Epoch 241/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0115 - val_loss: 0.0452
# Epoch 242/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0106 - val_loss: 0.0457
# Epoch 243/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0114 - val_loss: 0.0464
# Epoch 244/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0111 - val_loss: 0.0451
# Epoch 245/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0102 - val_loss: 0.0456
# Epoch 246/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0100 - val_loss: 0.0438
# Epoch 247/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0112 - val_loss: 0.0453
# Epoch 248/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0450
# Epoch 249/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0106 - val_loss: 0.0453
# Epoch 250/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0104 - val_loss: 0.0458
# Epoch 251/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0109 - val_loss: 0.0439
# Epoch 252/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0106 - val_loss: 0.0453
# Epoch 253/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0105 - val_loss: 0.0447
# Epoch 254/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0101 - val_loss: 0.0436
# Epoch 255/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0100 - val_loss: 0.0450
# Epoch 256/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0105 - val_loss: 0.0466
# Epoch 257/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0106 - val_loss: 0.0448
# Epoch 258/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0098 - val_loss: 0.0436
# Epoch 259/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0094 - val_loss: 0.0435
# Epoch 260/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0101 - val_loss: 0.0438
# Epoch 261/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0100 - val_loss: 0.0437
# Epoch 262/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0094 - val_loss: 0.0437
# Epoch 263/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0095 - val_loss: 0.0438
# Epoch 264/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0105 - val_loss: 0.0448
# Epoch 265/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0104 - val_loss: 0.0454
# Epoch 266/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0111 - val_loss: 0.0465
# Epoch 267/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0110 - val_loss: 0.0434
# Epoch 268/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0094 - val_loss: 0.0434
# Epoch 269/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0117 - val_loss: 0.0466
# Epoch 270/500
# 52/52 [==============================] - 1s 17ms/step - loss: 0.0101 - val_loss: 0.0455
# Epoch 271/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0101 - val_loss: 0.0440
# Epoch 272/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0099 - val_loss: 0.0444
# Epoch 273/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0094 - val_loss: 0.0446
# Epoch 274/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0101 - val_loss: 0.0453
# Epoch 275/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0108 - val_loss: 0.0453
# Epoch 276/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0454
# Epoch 277/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0102 - val_loss: 0.0440
# Epoch 278/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0101 - val_loss: 0.0451
# Epoch 279/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0093 - val_loss: 0.0456
# Epoch 280/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0095 - val_loss: 0.0453
# Epoch 281/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0442
# Epoch 282/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0089 - val_loss: 0.0446
# Epoch 283/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0103 - val_loss: 0.0445
# Epoch 284/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0096 - val_loss: 0.0444
# Epoch 285/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0105 - val_loss: 0.0443
# Epoch 286/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0102 - val_loss: 0.0440
# Epoch 287/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0100 - val_loss: 0.0454
# Epoch 288/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0107 - val_loss: 0.0448
# Epoch 289/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0097 - val_loss: 0.0448
# Epoch 290/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0098 - val_loss: 0.0438
# Epoch 291/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0456
# Epoch 292/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0098 - val_loss: 0.0438
# Epoch 293/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0448
# Epoch 294/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0446
# Epoch 295/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0437
# Epoch 296/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0445
# Epoch 297/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0099 - val_loss: 0.0447
# Epoch 298/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0446
# Epoch 299/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0098 - val_loss: 0.0446
# Epoch 300/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0440
# Epoch 301/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0460
# Epoch 302/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0086 - val_loss: 0.0461
# Epoch 303/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0110 - val_loss: 0.0452
# Epoch 304/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0451
# Epoch 305/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0448
# Epoch 306/500
# 52/52 [==============================] - ETA: 0s - loss: 0.009 - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0440
# Epoch 307/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0455
# Epoch 308/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0096 - val_loss: 0.0456
# Epoch 309/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0454
# Epoch 310/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0094 - val_loss: 0.0454
# Epoch 311/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0097 - val_loss: 0.0435
# Epoch 312/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0091 - val_loss: 0.0446
# Epoch 313/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0444
# Epoch 314/500
# 52/52 [==============================] - 1s 16ms/step - loss: 0.0091 - val_loss: 0.0443
# Epoch 315/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0089 - val_loss: 0.0453
# Epoch 316/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0106 - val_loss: 0.0456
# Epoch 317/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0097 - val_loss: 0.0449
# Epoch 318/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0089 - val_loss: 0.0454
# Epoch 319/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0090 - val_loss: 0.0441
# Epoch 320/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0445
# Epoch 321/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0443
# Epoch 322/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0451
# Epoch 323/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0090 - val_loss: 0.0438
# Epoch 324/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0088 - val_loss: 0.0442
# Epoch 325/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0440
# Epoch 326/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0087 - val_loss: 0.0455
# Epoch 327/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0095 - val_loss: 0.0451
# Epoch 328/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0092 - val_loss: 0.0450
# Epoch 329/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0092 - val_loss: 0.0442
# Epoch 330/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0452
# Epoch 331/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0446
# Epoch 332/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0444
# Epoch 333/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0448
# Epoch 334/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0090 - val_loss: 0.0456
# Epoch 335/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0088 - val_loss: 0.0439
# Epoch 336/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0094 - val_loss: 0.0448
# Epoch 337/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0437
# Epoch 338/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0093 - val_loss: 0.0445
# Epoch 339/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0093 - val_loss: 0.0442
# Epoch 340/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0447
# Epoch 341/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0444
# Epoch 342/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0086 - val_loss: 0.0443
# Epoch 343/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0452
# Epoch 344/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0438
# Epoch 345/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0459
# Epoch 346/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0447
# Epoch 347/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0453
# Epoch 348/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0445
# Epoch 349/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0455
# Epoch 350/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0460
# Epoch 351/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0108 - val_loss: 0.0448
# Epoch 352/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0086 - val_loss: 0.0451
# Epoch 353/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0449
# Epoch 354/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0438
# Epoch 355/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0088 - val_loss: 0.0444
# Epoch 356/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0451
# Epoch 357/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0440
# Epoch 358/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0441
# Epoch 359/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0448
# Epoch 360/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0095 - val_loss: 0.0447
# Epoch 361/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0089 - val_loss: 0.0446
# Epoch 362/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0448
# Epoch 363/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0091 - val_loss: 0.0452
# Epoch 364/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0099 - val_loss: 0.0454
# Epoch 365/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0449
# Epoch 366/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0448
# Epoch 367/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0448
# Epoch 368/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0445
# Epoch 369/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0076 - val_loss: 0.0449
# Epoch 370/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0097 - val_loss: 0.0440
# Epoch 371/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0444
# Epoch 372/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0087 - val_loss: 0.0454
# Epoch 373/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0090 - val_loss: 0.0446
# Epoch 374/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0452
# Epoch 375/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0082 - val_loss: 0.0449
# Epoch 376/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0450
# Epoch 377/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0091 - val_loss: 0.0451
# Epoch 378/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0444
# Epoch 379/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0450
# Epoch 380/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0445
# Epoch 381/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0459
# Epoch 382/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0451
# Epoch 383/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0453
# Epoch 384/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0079 - val_loss: 0.0447
# Epoch 385/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0086 - val_loss: 0.0438
# Epoch 386/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0092 - val_loss: 0.0449
# Epoch 387/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0086 - val_loss: 0.0452
# Epoch 388/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0442
# Epoch 389/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0449
# Epoch 390/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0457
# Epoch 391/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0446
# Epoch 392/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0448
# Epoch 393/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0079 - val_loss: 0.0446
# Epoch 394/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0079 - val_loss: 0.0455
# Epoch 395/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0443
# Epoch 396/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0450
# Epoch 397/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0080 - val_loss: 0.0440
# Epoch 398/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0444
# Epoch 399/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0078 - val_loss: 0.0448
# Epoch 400/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0429
# Epoch 401/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0451
# Epoch 402/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0083 - val_loss: 0.0449
# Epoch 403/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0444
# Epoch 404/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0085 - val_loss: 0.0448
# Epoch 405/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0088 - val_loss: 0.0458
# Epoch 406/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0086 - val_loss: 0.0461
# Epoch 407/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0090 - val_loss: 0.0453
# Epoch 408/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0086 - val_loss: 0.0457
# Epoch 409/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0445
# Epoch 410/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0078 - val_loss: 0.0453
# Epoch 411/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0083 - val_loss: 0.0449
# Epoch 412/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0080 - val_loss: 0.0451
# Epoch 413/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0445
# Epoch 414/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0455
# Epoch 415/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0451
# Epoch 416/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0078 - val_loss: 0.0451
# Epoch 417/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0445
# Epoch 418/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0446
# Epoch 419/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0445
# Epoch 420/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0446
# Epoch 421/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0075 - val_loss: 0.0441
# Epoch 422/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0072 - val_loss: 0.0437
# Epoch 423/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0447
# Epoch 424/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0083 - val_loss: 0.0443
# Epoch 425/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0078 - val_loss: 0.0443
# Epoch 426/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0082 - val_loss: 0.0441
# Epoch 427/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0080 - val_loss: 0.0441
# Epoch 428/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0084 - val_loss: 0.0451
# Epoch 429/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0446
# Epoch 430/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0440
# Epoch 431/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0450
# Epoch 432/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0085 - val_loss: 0.0442
# Epoch 433/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0444
# Epoch 434/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0446
# Epoch 435/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0453
# Epoch 436/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0079 - val_loss: 0.0443
# Epoch 437/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0075 - val_loss: 0.0445
# Epoch 438/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0074 - val_loss: 0.0449
# Epoch 439/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0071 - val_loss: 0.0435
# Epoch 440/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0077 - val_loss: 0.0444
# Epoch 441/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0075 - val_loss: 0.0438
# Epoch 442/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0451
# Epoch 443/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0080 - val_loss: 0.0451
# Epoch 444/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0442
# Epoch 445/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0453
# Epoch 446/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0444
# Epoch 447/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0087 - val_loss: 0.0442
# Epoch 448/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0443
# Epoch 449/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0431
# Epoch 450/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0453
# Epoch 451/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0438
# Epoch 452/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0440
# Epoch 453/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0445
# Epoch 454/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0076 - val_loss: 0.0453
# Epoch 455/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0440
# Epoch 456/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0451
# Epoch 457/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0456
# Epoch 458/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0456
# Epoch 459/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0429
# Epoch 460/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0445
# Epoch 461/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0441
# Epoch 462/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0445
# Epoch 463/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0089 - val_loss: 0.0459
# Epoch 464/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0434
# Epoch 465/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0439
# Epoch 466/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0073 - val_loss: 0.0448
# Epoch 467/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0446
# Epoch 468/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0074 - val_loss: 0.0437
# Epoch 469/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0449
# Epoch 470/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0083 - val_loss: 0.0441
# Epoch 471/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0444
# Epoch 472/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0068 - val_loss: 0.0438
# Epoch 473/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0455
# Epoch 474/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0436
# Epoch 475/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0077 - val_loss: 0.0441
# Epoch 476/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0081 - val_loss: 0.0455
# Epoch 477/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0452
# Epoch 478/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0067 - val_loss: 0.0439
# Epoch 479/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0449
# Epoch 480/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0073 - val_loss: 0.0445
# Epoch 481/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0443
# Epoch 482/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0080 - val_loss: 0.0445
# Epoch 483/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0443
# Epoch 484/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0077 - val_loss: 0.0449
# Epoch 485/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0076 - val_loss: 0.0435
# Epoch 486/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0449
# Epoch 487/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0084 - val_loss: 0.0448
# Epoch 488/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0439
# Epoch 489/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0088 - val_loss: 0.0438
# Epoch 490/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0078 - val_loss: 0.0445
# Epoch 491/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0069 - val_loss: 0.0439
# Epoch 492/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0072 - val_loss: 0.0446
# Epoch 493/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0077 - val_loss: 0.0443
# Epoch 494/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0071 - val_loss: 0.0451
# Epoch 495/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0083 - val_loss: 0.0441
# Epoch 496/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0070 - val_loss: 0.0450
# Epoch 497/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0075 - val_loss: 0.0444
# Epoch 498/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0072 - val_loss: 0.0437
# Epoch 499/500
# 52/52 [==============================] - 1s 15ms/step - loss: 0.0073 - val_loss: 0.0450
# Epoch 500/500
# 52/52 [==============================] - 1s 14ms/step - loss: 0.0079 - val_loss: 0.0446
